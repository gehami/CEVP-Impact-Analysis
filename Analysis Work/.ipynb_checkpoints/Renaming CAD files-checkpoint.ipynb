# %% [markdown]
# ### Importing Libraries

# %%
import os
import pandas as pd
import numpy as np
import datetime
from pytz import timezone

# %% [markdown]
# ### Constants

# %%
TRACKER_FILE_DIRECTORY = 'CAD data/tracker files'
MINIMUM_FILE_SIZE = 1000000 #one megabyte

KEEP_COLS = [0, 1, 4, 5, 6, 7, 8, 16, 17] #Marks all the columns from the initial files to keep. 

START_DATE = datetime.datetime(2018, 1, 1)

# %% [markdown]
# ### Identifying the list of files

# %%
files = os.listdir(TRACKER_FILE_DIRECTORY)

# %% [markdown]
# ### Renaming ending of files from .trk to .txt

# %%
for filename in files:
    original_file = TRACKER_FILE_DIRECTORY + '/' + filename
    new_file_name = original_file[:(len(original_file)-4)] + '.txt'
    #print(original_file)
    #print(new_file_name)
    os.rename(original_file, new_file_name)

# %% [markdown]
# ### Some of these files are clearly too small to have the amount of information we need.
# #### If they have less than 1000kb they should be removed
# #### Also, if the file is before 2018, it should also be removed. This can be done easily by removing any file that does not end with '2018.txt' or '2019.txt'

# %%
for filename in os.listdir(TRACKER_FILE_DIRECTORY):
    file_size = os.stat(TRACKER_FILE_DIRECTORY + '/' + filename).st_size
    if file_size < MINIMUM_FILE_SIZE:
        os.remove(TRACKER_FILE_DIRECTORY + '/' + filename)
    if filename[len(filename)- 6:] != '18.txt' and filename[len(filename)- 6:] != '19.txt':
        os.remove(TRACKER_FILE_DIRECTORY + '/' + filename)

# %% [markdown]
# ### Reading in a file row by row and parsing the information from it

# %%
def get_file_as_list (filename):


    full_file_dat = []

    with open(filename) as f:
        for line in f:
            line_split = line.split(sep = ' ') #works but we need to reunite the address
            addy = ' '.join(line_split[18:(len(line_split))]).strip()
            line_complete = line_split[0:18]

            line_complete.append(str(addy[1:(len(addy)-1)]))
            full_file_dat.append(line_complete)
    return full_file_dat;

# %% [markdown]
# ### Testing everything before creating the massive dataset

# %%
#testing to make sure the function works
test = get_file_as_list(TRACKER_FILE_DIRECTORY + '/' + os.listdir(TRACKER_FILE_DIRECTORY)[0])

#converting the test into a dataframe
test_arr = np.array(test)

#focusing only on the columns of interest
test_arr_clean = test_arr[:,KEEP_COLS]

#adding another bunch of rows
fin_test_arr = np.append(test_arr_clean, test_arr_clean, axis=0)

#print(test_arr[1,:])
#print(len(fin_test_arr))
#print(fin_test_arr)
#print(fin_test_arr.shape)
#all of this works. We are ready for takeoff.

# %% [markdown]
# ### Iterating through each file, creating an array, and appending it
# #### It's clear now that creating the massive dataset on our smol laptop is not going to end well. Instead, we are going to attempt to do all data cleaning here in python. This will be a good learning exercise as well as probably faster  (computationally) than R.

# %% [markdown]
# #### First we will need to order the files by date and open them within a 72-hour timeframe.
# We start with day 1 2 and 3, then day 2 3 and 4... and so on to make sure that any emergency that crosses between two days is accounted as a single journey, and that we only account for trips that started on the day of focus (rather than the one prior)

# %%
#start by getting the date on each file.
date_of_files = []
for file in os.listdir(TRACKER_FILE_DIRECTORY):
    #use os.stat().st_mtime to get the time of last modification to the file. 
    date_of_files.append([file,os.stat(TRACKER_FILE_DIRECTORY + '/' + file).st_mtime])

#convert this into a numpy array where column 1 is the filenames and column 2 is the last modified time
arr_of_files = np.array(date_of_files)
#converting again into a pandas df
files_df = pd.DataFrame({'file_name':arr_of_files[:,0], 'mod_time':arr_of_files[:,1]})


#order the df based on the second column
files_df = files_df.sort_values(by = ['mod_time'])

files_in_date_order = []

#checking to make sure they are in the correct order if I were to iterate through it.
for file in files_df['file_name']:
    #print(file)
    files_in_date_order.append(file)
#yup. Works.     

print(files_in_date_order[0:4])
# Out:
# ['TrackerArchive_SJFIR_01-01-2018.txt', 'TrackerArchive_SJFIR_01-02-2018.txt', 'TrackerArchive_SJFIR_01-03-2018.txt', 'TrackerArchive_SJFIR_01-04-2018.txt']

# %% [markdown]
# #### Now we can open two files in order of days fairly easily. Next we will need to open three files, and get all of the trips that started in the SECOND day.
# The first day is to identify the trips that began in the prior day. The third day is to show the ending of trips that started in the second day. The second day is the day of focus.

# %%
#This is all just test and not relevant to work

#opening three files and converting them to dataframes. 
#i = 1

#file_0 = pd.DataFrame(np.array(get_file_as_list(TRACKER_FILE_DIRECTORY + '/' + files_in_date_order[i-1]))[:,KEEP_COLS])
#file_1 = pd.DataFrame(np.array(get_file_as_list(TRACKER_FILE_DIRECTORY + '/' + files_in_date_order[i]))[:,KEEP_COLS])
#file_2 = pd.DataFrame(np.array(get_file_as_list(TRACKER_FILE_DIRECTORY + '/' + files_in_date_order[i+1]))[:,KEEP_COLS])

#adding colnames to dfs.
#COLUMN_NAMES = ['datetime', 'utc', 'veh_id', 'lat', 'lon', 'type', 'trip_id']
#file_0.columns = COLUMN_NAMES
#file_1.columns = COLUMN_NAMES
#file_2.columns = COLUMN_NAMES


#print(file_1.head(3))#works

#file = pd.concat([file_0, file_1, file_2], axis = 0)


#FOCUS_DATE = datetime.date(int(file_1['datetime'][0][0:4]), int(file_1['datetime'][0][4:6]), int(file_1['datetime'][0][6:8]))
#VALID_TRIP_TYPES = ['ER', 'AR', 'AD']
#ARRIVAL_TYPES = ['AR', 'AD']

# %%
#converting the datetime column into a datetime value. 
def add_date (file):
    dt = file['datetime']

    dt_fin = []
    #let's see if we can get a date-time var

    #so we are struggling to make the dt var work perfectly. For some reason it is 7 minutes earlier than it should be. 
    #to make a quick fix, let's just make a naive dt var, since we only need to identify the date that a 

    for one_dt in dt:
        year = one_dt[0:4]
        month = one_dt[4:6]
        day = one_dt[6:8]
        #hour = one_dt[8:10]
        #minute = one_dt[10:12]
        #second = one_dt[12:14]
        #timezone = one_dt[14:16]
        #print(year, month, day, hour, minute, second, timezone)
        dt_fin.append(datetime.date(int(year), int(month), int(day)))#, int(hour), int(minute), int(second), tzinfo = TIMEZONE))

    #seems to work? 
    #print(dt_fin[0:4])
    #it works well enough for what we want to do in python. 
    file['date'] = dt_fin
    
    return file;

# %%
#now we need to identify the starting date of each trip. We can do this by first ordering the df by veh_id and then by trip_id.
#from there we will see if the row above has the same veh_id and trip_id. If it does, then it gets the same start_date.
#If not, then it gets its own start date. 

#1) the addy column is bunk so don't bother with it.
#2) The data logged only matters when the vehicle is actually en-route and has arrived. These are codes ER, AR, and AD (arrived dangerously) 
#    This may not be the case, as some of the other trip status Ids might be worth noting,
#    but it seems like at least we can drop any observations with no trip_id attached, as those are just idle trucks. 


def get_valid_trips_and_start_date (file, VALID_TRIP_TYPES):

    #dropping all observations with no trip_id and keeping only observations with a valid trip type
    trip_file = file[file.trip_id != ""]
    trip_file = trip_file[trip_file['type'].isin(VALID_TRIP_TYPES)]


    #ordering the df
    trip_file = trip_file.sort_values(by = ['veh_id', 'trip_id', 'datetime'])
    trip_file = trip_file.reset_index(drop = True)

    #initializing new vars
    start_date_vec = [trip_file['date'][0]]



    #iterating through df to get the start date for each trip
    for i in range(1,len(trip_file['veh_id'])):

        if(trip_file['veh_id'][i] == trip_file['veh_id'][i-1] and trip_file['trip_id'][i] == trip_file['trip_id'][i-1]):
            start_date_vec.append(start_date_vec[i-1])
        else:
            start_date_vec.append(trip_file['date'][i])

    trip_file['start_date'] = start_date_vec
    #works
    return trip_file;

# %%
#Now we can remove all of the obs that do not have a start date of the FOCUS_DATE
def get_fin_trip_file (trip_file, FOCUS_DATE, ARRIVAL_TYPES):

    fin_trip_file = trip_file[trip_file['start_date'] == FOCUS_DATE]
    fin_trip_file = fin_trip_file.reset_index(drop = True)

    #Lastly, let's iterate through, identify the point of arrival for each trip, 
    #and mark any additional recordings for arrival for removal
    repeat_arrival_obs = np.repeat(0, len(fin_trip_file))


    for i in range(1, len(repeat_arrival_obs)):
        if fin_trip_file['type'][i] in ARRIVAL_TYPES:
            if fin_trip_file['type'][i-1] in ARRIVAL_TYPES:
                if (fin_trip_file['veh_id'][i] == fin_trip_file['veh_id'][i-1] and\
                    fin_trip_file['trip_id'][i] == fin_trip_file['trip_id'][i-1]):
                    repeat_arrival_obs[i] = 1
                    #print(fin_trip_file.iloc[i-1])
                    #print(fin_trip_file.iloc[i])
    #the above loop works

    #removing repeat arrival log data.
    fin_trip_file = fin_trip_file[repeat_arrival_obs < 1]
    fin_trip_file = fin_trip_file.reset_index(drop = True)

    #fin_trip_file.head(4)
    #print(len(fin_trip_file))
    #works
    return fin_trip_file;

# %% [markdown]
# ### Now that the functions have been defined, we will run through every file, format and save it into a new folder.

# %%
#setting up the constants
VALID_TRIP_TYPES = ['ER', 'AR', 'AD']
ARRIVAL_TYPES = ['AR', 'AD']
DESTINATION_FOLDER = 'CAD Data/Trip Files'





for i in range(1, len(files_in_date_order) - 1):
    
    #opening three files and converting them to dataframes. 
    file_0 = pd.DataFrame(np.array(get_file_as_list(TRACKER_FILE_DIRECTORY + '/' + files_in_date_order[i-1]))[:,KEEP_COLS])
    file_1 = pd.DataFrame(np.array(get_file_as_list(TRACKER_FILE_DIRECTORY + '/' + files_in_date_order[i]))[:,KEEP_COLS])
    file_2 = pd.DataFrame(np.array(get_file_as_list(TRACKER_FILE_DIRECTORY + '/' + files_in_date_order[i+1]))[:,KEEP_COLS])

    #adding colnames to dfs.
    COLUMN_NAMES = ['datetime', 'utc', 'veh_id', 'lat', 'lon', 'x', 'y', 'type', 'trip_id']
    file_0.columns = COLUMN_NAMES
    file_1.columns = COLUMN_NAMES
    file_2.columns = COLUMN_NAMES

    #creating single file
    file = pd.concat([file_0, file_1, file_2], axis = 0)

    #marking date of focus for this file
    FOCUS_DATE = datetime.date(int(file_1['datetime'][0][0:4]), int(file_1['datetime'][0][4:6]), int(file_1['datetime'][0][6:8]))

    #making the final dataset
    file_step_1 = add_date(file)
    file_step_2 = get_valid_trips_and_start_date(file_step_1, VALID_TRIP_TYPES)
    fin_file = get_fin_trip_file(file_step_2, FOCUS_DATE, ARRIVAL_TYPES)

    file_path = str(DESTINATION_FOLDER + '/trips starting ' + str(FOCUS_DATE) + '.csv')
    print(file_path)
    fin_file.to_csv(file_path, index = False, sep = ',')
# Out:
# CAD Data/Trip Files/trips starting 2018-01-02.csv
# CAD Data/Trip Files/trips starting 2018-01-03.csv
# CAD Data/Trip Files/trips starting 2018-01-04.csv
# CAD Data/Trip Files/trips starting 2018-01-05.csv
# CAD Data/Trip Files/trips starting 2018-01-06.csv
# CAD Data/Trip Files/trips starting 2018-01-07.csv
# CAD Data/Trip Files/trips starting 2018-01-08.csv
# CAD Data/Trip Files/trips starting 2018-01-09.csv
# CAD Data/Trip Files/trips starting 2018-01-10.csv
# CAD Data/Trip Files/trips starting 2018-01-11.csv
# CAD Data/Trip Files/trips starting 2018-01-12.csv
# CAD Data/Trip Files/trips starting 2018-01-13.csv
# CAD Data/Trip Files/trips starting 2018-01-14.csv
# CAD Data/Trip Files/trips starting 2018-01-15.csv
# CAD Data/Trip Files/trips starting 2018-01-16.csv
# CAD Data/Trip Files/trips starting 2018-01-17.csv
# CAD Data/Trip Files/trips starting 2018-01-18.csv
# CAD Data/Trip Files/trips starting 2018-01-19.csv
# CAD Data/Trip Files/trips starting 2018-01-20.csv
# CAD Data/Trip Files/trips starting 2018-01-21.csv
# CAD Data/Trip Files/trips starting 2018-01-22.csv
# CAD Data/Trip Files/trips starting 2018-01-23.csv
# CAD Data/Trip Files/trips starting 2018-01-24.csv
# CAD Data/Trip Files/trips starting 2018-01-25.csv
# CAD Data/Trip Files/trips starting 2018-01-26.csv
# CAD Data/Trip Files/trips starting 2018-01-27.csv
# CAD Data/Trip Files/trips starting 2018-01-28.csv
# CAD Data/Trip Files/trips starting 2018-01-29.csv
# CAD Data/Trip Files/trips starting 2018-01-30.csv
# CAD Data/Trip Files/trips starting 2018-01-31.csv
# CAD Data/Trip Files/trips starting 2018-02-01.csv
# CAD Data/Trip Files/trips starting 2018-02-02.csv
# CAD Data/Trip Files/trips starting 2018-02-03.csv
# CAD Data/Trip Files/trips starting 2018-02-04.csv
# CAD Data/Trip Files/trips starting 2018-02-05.csv
# CAD Data/Trip Files/trips starting 2018-02-06.csv
# CAD Data/Trip Files/trips starting 2018-02-07.csv
# CAD Data/Trip Files/trips starting 2018-02-08.csv
# CAD Data/Trip Files/trips starting 2018-02-09.csv
# CAD Data/Trip Files/trips starting 2018-02-10.csv
# CAD Data/Trip Files/trips starting 2018-02-11.csv
# CAD Data/Trip Files/trips starting 2018-02-12.csv
# CAD Data/Trip Files/trips starting 2018-02-13.csv
# CAD Data/Trip Files/trips starting 2018-02-14.csv
# CAD Data/Trip Files/trips starting 2018-02-15.csv
# CAD Data/Trip Files/trips starting 2018-02-16.csv
# CAD Data/Trip Files/trips starting 2018-02-17.csv
# CAD Data/Trip Files/trips starting 2018-02-18.csv
# CAD Data/Trip Files/trips starting 2018-02-19.csv
# CAD Data/Trip Files/trips starting 2018-02-20.csv
# CAD Data/Trip Files/trips starting 2018-02-21.csv
# CAD Data/Trip Files/trips starting 2018-02-22.csv
# CAD Data/Trip Files/trips starting 2018-02-23.csv
# CAD Data/Trip Files/trips starting 2018-02-24.csv
# CAD Data/Trip Files/trips starting 2018-02-25.csv
# CAD Data/Trip Files/trips starting 2018-02-26.csv
# CAD Data/Trip Files/trips starting 2018-02-27.csv
# CAD Data/Trip Files/trips starting 2018-02-28.csv
# CAD Data/Trip Files/trips starting 2018-03-01.csv
# CAD Data/Trip Files/trips starting 2018-03-02.csv
# CAD Data/Trip Files/trips starting 2018-03-03.csv
# CAD Data/Trip Files/trips starting 2018-03-04.csv
# CAD Data/Trip Files/trips starting 2018-03-05.csv
# CAD Data/Trip Files/trips starting 2018-03-06.csv
# CAD Data/Trip Files/trips starting 2018-03-07.csv
# CAD Data/Trip Files/trips starting 2018-03-08.csv
# CAD Data/Trip Files/trips starting 2018-03-09.csv
# CAD Data/Trip Files/trips starting 2018-03-10.csv
# CAD Data/Trip Files/trips starting 2018-03-11.csv
# CAD Data/Trip Files/trips starting 2018-03-12.csv
# CAD Data/Trip Files/trips starting 2018-03-13.csv
# CAD Data/Trip Files/trips starting 2018-03-14.csv
# CAD Data/Trip Files/trips starting 2018-03-15.csv
# CAD Data/Trip Files/trips starting 2018-03-16.csv
# CAD Data/Trip Files/trips starting 2018-03-17.csv
# CAD Data/Trip Files/trips starting 2018-03-18.csv
# CAD Data/Trip Files/trips starting 2018-03-19.csv
# CAD Data/Trip Files/trips starting 2018-03-20.csv
# CAD Data/Trip Files/trips starting 2018-03-21.csv
# CAD Data/Trip Files/trips starting 2018-03-22.csv
# CAD Data/Trip Files/trips starting 2018-03-23.csv
# CAD Data/Trip Files/trips starting 2018-03-24.csv
# CAD Data/Trip Files/trips starting 2018-03-25.csv
# CAD Data/Trip Files/trips starting 2018-03-26.csv
# CAD Data/Trip Files/trips starting 2018-03-27.csv
# CAD Data/Trip Files/trips starting 2018-03-28.csv
# CAD Data/Trip Files/trips starting 2018-03-29.csv
# CAD Data/Trip Files/trips starting 2018-03-30.csv
# CAD Data/Trip Files/trips starting 2018-03-31.csv
# CAD Data/Trip Files/trips starting 2018-04-01.csv
# CAD Data/Trip Files/trips starting 2018-04-02.csv
# CAD Data/Trip Files/trips starting 2018-04-03.csv
# CAD Data/Trip Files/trips starting 2018-04-04.csv
# CAD Data/Trip Files/trips starting 2018-04-05.csv
# CAD Data/Trip Files/trips starting 2018-04-06.csv
# CAD Data/Trip Files/trips starting 2018-04-07.csv
# CAD Data/Trip Files/trips starting 2018-04-08.csv
# CAD Data/Trip Files/trips starting 2018-04-09.csv
# CAD Data/Trip Files/trips starting 2018-04-10.csv
# CAD Data/Trip Files/trips starting 2018-04-11.csv
# CAD Data/Trip Files/trips starting 2018-04-12.csv
# CAD Data/Trip Files/trips starting 2018-04-13.csv
# CAD Data/Trip Files/trips starting 2018-04-14.csv
# CAD Data/Trip Files/trips starting 2018-04-15.csv
# CAD Data/Trip Files/trips starting 2018-04-16.csv
# CAD Data/Trip Files/trips starting 2018-04-17.csv
# CAD Data/Trip Files/trips starting 2018-04-18.csv
# CAD Data/Trip Files/trips starting 2018-04-19.csv
# CAD Data/Trip Files/trips starting 2018-04-20.csv
# CAD Data/Trip Files/trips starting 2018-04-21.csv
# CAD Data/Trip Files/trips starting 2018-04-22.csv
# CAD Data/Trip Files/trips starting 2018-04-23.csv
# CAD Data/Trip Files/trips starting 2018-04-24.csv
# CAD Data/Trip Files/trips starting 2018-04-25.csv
# CAD Data/Trip Files/trips starting 2018-04-26.csv
# CAD Data/Trip Files/trips starting 2018-04-27.csv
# CAD Data/Trip Files/trips starting 2018-04-28.csv
# CAD Data/Trip Files/trips starting 2018-04-29.csv
# CAD Data/Trip Files/trips starting 2018-04-30.csv
# CAD Data/Trip Files/trips starting 2018-05-01.csv
# CAD Data/Trip Files/trips starting 2018-05-02.csv
# CAD Data/Trip Files/trips starting 2018-05-03.csv
# CAD Data/Trip Files/trips starting 2018-05-04.csv
# CAD Data/Trip Files/trips starting 2018-05-05.csv
# CAD Data/Trip Files/trips starting 2018-05-06.csv
# CAD Data/Trip Files/trips starting 2018-05-07.csv
# CAD Data/Trip Files/trips starting 2018-05-08.csv
# CAD Data/Trip Files/trips starting 2018-05-09.csv
# CAD Data/Trip Files/trips starting 2018-05-10.csv
# CAD Data/Trip Files/trips starting 2018-05-11.csv
# CAD Data/Trip Files/trips starting 2018-05-12.csv
# CAD Data/Trip Files/trips starting 2018-05-13.csv
# CAD Data/Trip Files/trips starting 2018-05-14.csv
# CAD Data/Trip Files/trips starting 2018-05-15.csv
# CAD Data/Trip Files/trips starting 2018-05-16.csv
# CAD Data/Trip Files/trips starting 2018-05-17.csv
# CAD Data/Trip Files/trips starting 2018-05-18.csv
# CAD Data/Trip Files/trips starting 2018-05-19.csv
# CAD Data/Trip Files/trips starting 2018-05-20.csv
# CAD Data/Trip Files/trips starting 2018-05-21.csv
# CAD Data/Trip Files/trips starting 2018-05-22.csv
# CAD Data/Trip Files/trips starting 2018-05-23.csv
# CAD Data/Trip Files/trips starting 2018-05-24.csv
# CAD Data/Trip Files/trips starting 2018-05-25.csv
# CAD Data/Trip Files/trips starting 2018-05-26.csv
# CAD Data/Trip Files/trips starting 2018-05-27.csv
# CAD Data/Trip Files/trips starting 2018-05-28.csv
# CAD Data/Trip Files/trips starting 2018-05-29.csv
# CAD Data/Trip Files/trips starting 2018-05-30.csv
# CAD Data/Trip Files/trips starting 2018-05-31.csv
# CAD Data/Trip Files/trips starting 2018-06-01.csv
# CAD Data/Trip Files/trips starting 2018-06-02.csv
# CAD Data/Trip Files/trips starting 2018-06-03.csv
# CAD Data/Trip Files/trips starting 2018-06-04.csv
# CAD Data/Trip Files/trips starting 2018-06-05.csv
# CAD Data/Trip Files/trips starting 2018-06-06.csv
# CAD Data/Trip Files/trips starting 2018-06-07.csv
# CAD Data/Trip Files/trips starting 2018-06-08.csv
# CAD Data/Trip Files/trips starting 2018-06-09.csv
# CAD Data/Trip Files/trips starting 2018-06-10.csv
# CAD Data/Trip Files/trips starting 2018-06-11.csv
# CAD Data/Trip Files/trips starting 2018-06-12.csv
# CAD Data/Trip Files/trips starting 2018-06-13.csv
# CAD Data/Trip Files/trips starting 2018-06-14.csv
# CAD Data/Trip Files/trips starting 2018-06-15.csv
# CAD Data/Trip Files/trips starting 2018-06-16.csv
# CAD Data/Trip Files/trips starting 2018-06-17.csv
# CAD Data/Trip Files/trips starting 2018-06-18.csv
# CAD Data/Trip Files/trips starting 2018-06-19.csv
# CAD Data/Trip Files/trips starting 2018-06-20.csv
# CAD Data/Trip Files/trips starting 2018-06-21.csv
# CAD Data/Trip Files/trips starting 2018-06-22.csv
# CAD Data/Trip Files/trips starting 2018-06-23.csv
# CAD Data/Trip Files/trips starting 2018-06-24.csv
# CAD Data/Trip Files/trips starting 2018-06-25.csv
# CAD Data/Trip Files/trips starting 2018-06-26.csv
# CAD Data/Trip Files/trips starting 2018-06-27.csv
# CAD Data/Trip Files/trips starting 2018-06-28.csv
# CAD Data/Trip Files/trips starting 2018-06-29.csv
# CAD Data/Trip Files/trips starting 2018-06-30.csv
# CAD Data/Trip Files/trips starting 2018-07-01.csv
# CAD Data/Trip Files/trips starting 2018-07-02.csv
# CAD Data/Trip Files/trips starting 2018-07-03.csv
# CAD Data/Trip Files/trips starting 2018-07-04.csv
# CAD Data/Trip Files/trips starting 2018-07-05.csv
# CAD Data/Trip Files/trips starting 2018-07-06.csv
# CAD Data/Trip Files/trips starting 2018-07-07.csv
# CAD Data/Trip Files/trips starting 2018-07-08.csv
# CAD Data/Trip Files/trips starting 2018-07-09.csv
# CAD Data/Trip Files/trips starting 2018-07-10.csv
# CAD Data/Trip Files/trips starting 2018-07-11.csv
# CAD Data/Trip Files/trips starting 2018-07-12.csv
# CAD Data/Trip Files/trips starting 2018-07-13.csv
# CAD Data/Trip Files/trips starting 2018-07-14.csv
# CAD Data/Trip Files/trips starting 2018-07-15.csv
# CAD Data/Trip Files/trips starting 2018-07-16.csv
# CAD Data/Trip Files/trips starting 2018-07-17.csv
# CAD Data/Trip Files/trips starting 2018-07-18.csv
# CAD Data/Trip Files/trips starting 2018-07-19.csv
# CAD Data/Trip Files/trips starting 2018-07-20.csv
# CAD Data/Trip Files/trips starting 2018-07-21.csv
# CAD Data/Trip Files/trips starting 2018-07-22.csv
# CAD Data/Trip Files/trips starting 2018-07-23.csv
# CAD Data/Trip Files/trips starting 2018-07-24.csv
# CAD Data/Trip Files/trips starting 2018-07-25.csv
# CAD Data/Trip Files/trips starting 2018-07-26.csv
# CAD Data/Trip Files/trips starting 2018-07-27.csv
# CAD Data/Trip Files/trips starting 2018-07-28.csv
# CAD Data/Trip Files/trips starting 2018-07-29.csv
# CAD Data/Trip Files/trips starting 2018-07-30.csv
# CAD Data/Trip Files/trips starting 2018-07-31.csv
# CAD Data/Trip Files/trips starting 2018-08-01.csv
# CAD Data/Trip Files/trips starting 2018-08-02.csv
# CAD Data/Trip Files/trips starting 2018-08-03.csv
# CAD Data/Trip Files/trips starting 2018-08-04.csv
# CAD Data/Trip Files/trips starting 2018-08-05.csv
# CAD Data/Trip Files/trips starting 2018-08-06.csv
# CAD Data/Trip Files/trips starting 2018-08-07.csv
# CAD Data/Trip Files/trips starting 2018-08-08.csv
# CAD Data/Trip Files/trips starting 2018-08-09.csv
# CAD Data/Trip Files/trips starting 2018-08-10.csv
# CAD Data/Trip Files/trips starting 2018-08-11.csv
# CAD Data/Trip Files/trips starting 2018-08-12.csv
# CAD Data/Trip Files/trips starting 2018-08-13.csv
# CAD Data/Trip Files/trips starting 2018-08-14.csv
# CAD Data/Trip Files/trips starting 2018-08-15.csv
# CAD Data/Trip Files/trips starting 2018-08-16.csv
# CAD Data/Trip Files/trips starting 2018-08-17.csv
# CAD Data/Trip Files/trips starting 2018-08-18.csv
# CAD Data/Trip Files/trips starting 2018-08-19.csv
# CAD Data/Trip Files/trips starting 2018-08-20.csv
# CAD Data/Trip Files/trips starting 2018-08-21.csv
# CAD Data/Trip Files/trips starting 2018-08-22.csv
# CAD Data/Trip Files/trips starting 2018-08-23.csv
# CAD Data/Trip Files/trips starting 2018-08-24.csv
# CAD Data/Trip Files/trips starting 2018-08-25.csv
# CAD Data/Trip Files/trips starting 2018-08-26.csv
# CAD Data/Trip Files/trips starting 2018-08-27.csv
# CAD Data/Trip Files/trips starting 2018-08-28.csv
# CAD Data/Trip Files/trips starting 2018-08-29.csv
# CAD Data/Trip Files/trips starting 2018-08-30.csv
# CAD Data/Trip Files/trips starting 2018-08-31.csv
# CAD Data/Trip Files/trips starting 2018-09-01.csv
# CAD Data/Trip Files/trips starting 2018-09-02.csv
# CAD Data/Trip Files/trips starting 2018-09-03.csv
# CAD Data/Trip Files/trips starting 2018-09-04.csv
# CAD Data/Trip Files/trips starting 2018-09-05.csv
# CAD Data/Trip Files/trips starting 2018-09-06.csv
# CAD Data/Trip Files/trips starting 2018-09-07.csv
# CAD Data/Trip Files/trips starting 2018-09-08.csv
# CAD Data/Trip Files/trips starting 2018-09-09.csv
# CAD Data/Trip Files/trips starting 2018-09-10.csv
# CAD Data/Trip Files/trips starting 2018-09-11.csv
# CAD Data/Trip Files/trips starting 2018-09-12.csv
# CAD Data/Trip Files/trips starting 2018-09-13.csv
# CAD Data/Trip Files/trips starting 2018-09-14.csv
# CAD Data/Trip Files/trips starting 2018-09-15.csv
# CAD Data/Trip Files/trips starting 2018-09-16.csv
# CAD Data/Trip Files/trips starting 2018-09-17.csv
# CAD Data/Trip Files/trips starting 2018-09-18.csv
# CAD Data/Trip Files/trips starting 2018-09-19.csv
# CAD Data/Trip Files/trips starting 2018-09-20.csv
# CAD Data/Trip Files/trips starting 2018-09-21.csv
# CAD Data/Trip Files/trips starting 2018-09-22.csv
# CAD Data/Trip Files/trips starting 2018-09-23.csv
# CAD Data/Trip Files/trips starting 2018-09-24.csv
# CAD Data/Trip Files/trips starting 2018-09-25.csv
# CAD Data/Trip Files/trips starting 2018-09-26.csv
# CAD Data/Trip Files/trips starting 2018-09-27.csv
# CAD Data/Trip Files/trips starting 2018-09-28.csv
# CAD Data/Trip Files/trips starting 2018-09-29.csv
# CAD Data/Trip Files/trips starting 2018-09-30.csv
# CAD Data/Trip Files/trips starting 2018-10-01.csv
# CAD Data/Trip Files/trips starting 2018-10-02.csv
# CAD Data/Trip Files/trips starting 2018-10-03.csv
# CAD Data/Trip Files/trips starting 2018-10-04.csv
# CAD Data/Trip Files/trips starting 2018-10-05.csv
# CAD Data/Trip Files/trips starting 2018-10-06.csv
# CAD Data/Trip Files/trips starting 2018-10-07.csv
# CAD Data/Trip Files/trips starting 2018-10-08.csv
# CAD Data/Trip Files/trips starting 2018-10-09.csv
# CAD Data/Trip Files/trips starting 2018-10-10.csv
# CAD Data/Trip Files/trips starting 2018-10-11.csv
# CAD Data/Trip Files/trips starting 2018-10-12.csv
# CAD Data/Trip Files/trips starting 2018-10-13.csv
# CAD Data/Trip Files/trips starting 2018-10-14.csv
# CAD Data/Trip Files/trips starting 2018-10-15.csv
# CAD Data/Trip Files/trips starting 2018-10-16.csv
# CAD Data/Trip Files/trips starting 2018-10-17.csv
# CAD Data/Trip Files/trips starting 2018-10-18.csv
# CAD Data/Trip Files/trips starting 2018-10-19.csv
# CAD Data/Trip Files/trips starting 2018-10-20.csv
# CAD Data/Trip Files/trips starting 2018-10-21.csv
# CAD Data/Trip Files/trips starting 2018-10-22.csv
# CAD Data/Trip Files/trips starting 2018-10-23.csv
# CAD Data/Trip Files/trips starting 2018-10-24.csv
# CAD Data/Trip Files/trips starting 2018-10-25.csv
# CAD Data/Trip Files/trips starting 2018-10-26.csv
# CAD Data/Trip Files/trips starting 2018-10-27.csv
# CAD Data/Trip Files/trips starting 2018-10-28.csv
# CAD Data/Trip Files/trips starting 2018-10-29.csv
# CAD Data/Trip Files/trips starting 2018-10-30.csv
# CAD Data/Trip Files/trips starting 2018-10-31.csv
# CAD Data/Trip Files/trips starting 2018-11-01.csv
# CAD Data/Trip Files/trips starting 2018-11-02.csv
# CAD Data/Trip Files/trips starting 2018-11-03.csv
# CAD Data/Trip Files/trips starting 2018-11-04.csv
# CAD Data/Trip Files/trips starting 2018-11-05.csv
# CAD Data/Trip Files/trips starting 2018-11-06.csv
# CAD Data/Trip Files/trips starting 2018-11-07.csv
# CAD Data/Trip Files/trips starting 2018-11-08.csv
# CAD Data/Trip Files/trips starting 2018-11-09.csv
# CAD Data/Trip Files/trips starting 2018-11-10.csv
# CAD Data/Trip Files/trips starting 2018-11-11.csv
# CAD Data/Trip Files/trips starting 2018-11-12.csv
# CAD Data/Trip Files/trips starting 2018-11-13.csv
# CAD Data/Trip Files/trips starting 2018-11-14.csv
# CAD Data/Trip Files/trips starting 2018-11-15.csv
# CAD Data/Trip Files/trips starting 2018-11-16.csv
# CAD Data/Trip Files/trips starting 2018-11-17.csv
# CAD Data/Trip Files/trips starting 2018-11-18.csv
# CAD Data/Trip Files/trips starting 2018-11-19.csv
# CAD Data/Trip Files/trips starting 2018-11-20.csv
# CAD Data/Trip Files/trips starting 2018-11-21.csv
# CAD Data/Trip Files/trips starting 2018-11-22.csv
# CAD Data/Trip Files/trips starting 2018-11-23.csv
# CAD Data/Trip Files/trips starting 2018-11-24.csv
# CAD Data/Trip Files/trips starting 2018-11-25.csv
# CAD Data/Trip Files/trips starting 2018-11-26.csv
# CAD Data/Trip Files/trips starting 2018-11-27.csv
# CAD Data/Trip Files/trips starting 2018-11-28.csv
# CAD Data/Trip Files/trips starting 2018-11-29.csv
# CAD Data/Trip Files/trips starting 2018-11-30.csv
# CAD Data/Trip Files/trips starting 2018-12-01.csv
# CAD Data/Trip Files/trips starting 2018-12-02.csv
# CAD Data/Trip Files/trips starting 2018-12-03.csv
# CAD Data/Trip Files/trips starting 2018-12-04.csv
# CAD Data/Trip Files/trips starting 2018-12-05.csv
# CAD Data/Trip Files/trips starting 2018-12-06.csv
# CAD Data/Trip Files/trips starting 2018-12-07.csv
# CAD Data/Trip Files/trips starting 2018-12-08.csv
# CAD Data/Trip Files/trips starting 2018-12-09.csv
# CAD Data/Trip Files/trips starting 2018-12-10.csv
# CAD Data/Trip Files/trips starting 2018-12-11.csv
# CAD Data/Trip Files/trips starting 2018-12-12.csv
# CAD Data/Trip Files/trips starting 2018-12-13.csv
# CAD Data/Trip Files/trips starting 2018-12-14.csv
# CAD Data/Trip Files/trips starting 2018-12-15.csv
# CAD Data/Trip Files/trips starting 2018-12-16.csv
# CAD Data/Trip Files/trips starting 2018-12-17.csv
# CAD Data/Trip Files/trips starting 2018-12-18.csv
# CAD Data/Trip Files/trips starting 2018-12-19.csv
# CAD Data/Trip Files/trips starting 2018-12-20.csv
# CAD Data/Trip Files/trips starting 2018-12-21.csv
# CAD Data/Trip Files/trips starting 2018-12-22.csv
# CAD Data/Trip Files/trips starting 2018-12-23.csv
# CAD Data/Trip Files/trips starting 2018-12-24.csv
# CAD Data/Trip Files/trips starting 2018-12-25.csv
# CAD Data/Trip Files/trips starting 2018-12-26.csv
# CAD Data/Trip Files/trips starting 2018-12-27.csv
# CAD Data/Trip Files/trips starting 2018-12-28.csv
# CAD Data/Trip Files/trips starting 2018-12-29.csv
# CAD Data/Trip Files/trips starting 2018-12-30.csv
# CAD Data/Trip Files/trips starting 2018-12-31.csv
# CAD Data/Trip Files/trips starting 2019-01-01.csv
# CAD Data/Trip Files/trips starting 2019-01-02.csv
# CAD Data/Trip Files/trips starting 2019-01-03.csv
# CAD Data/Trip Files/trips starting 2019-01-04.csv
# CAD Data/Trip Files/trips starting 2019-01-05.csv
# CAD Data/Trip Files/trips starting 2019-01-06.csv
# CAD Data/Trip Files/trips starting 2019-01-07.csv
# CAD Data/Trip Files/trips starting 2019-01-08.csv
# CAD Data/Trip Files/trips starting 2019-01-09.csv
# CAD Data/Trip Files/trips starting 2019-01-10.csv
# CAD Data/Trip Files/trips starting 2019-01-11.csv
# CAD Data/Trip Files/trips starting 2019-01-12.csv
# CAD Data/Trip Files/trips starting 2019-01-13.csv
# CAD Data/Trip Files/trips starting 2019-01-14.csv
# CAD Data/Trip Files/trips starting 2019-01-15.csv
# CAD Data/Trip Files/trips starting 2019-01-16.csv
# CAD Data/Trip Files/trips starting 2019-01-17.csv
# CAD Data/Trip Files/trips starting 2019-01-18.csv
# CAD Data/Trip Files/trips starting 2019-01-19.csv
# CAD Data/Trip Files/trips starting 2019-01-20.csv
# CAD Data/Trip Files/trips starting 2019-01-21.csv
# CAD Data/Trip Files/trips starting 2019-01-22.csv
# CAD Data/Trip Files/trips starting 2019-01-23.csv
# CAD Data/Trip Files/trips starting 2019-01-24.csv
# CAD Data/Trip Files/trips starting 2019-01-25.csv
# CAD Data/Trip Files/trips starting 2019-01-26.csv
# CAD Data/Trip Files/trips starting 2019-01-27.csv
# CAD Data/Trip Files/trips starting 2019-01-28.csv
# CAD Data/Trip Files/trips starting 2019-01-29.csv
# CAD Data/Trip Files/trips starting 2019-01-30.csv
# CAD Data/Trip Files/trips starting 2019-01-31.csv
# CAD Data/Trip Files/trips starting 2019-02-01.csv
# CAD Data/Trip Files/trips starting 2019-02-02.csv
# CAD Data/Trip Files/trips starting 2019-02-03.csv
# CAD Data/Trip Files/trips starting 2019-02-04.csv
# CAD Data/Trip Files/trips starting 2019-02-05.csv
# CAD Data/Trip Files/trips starting 2019-02-06.csv
# CAD Data/Trip Files/trips starting 2019-02-07.csv
# CAD Data/Trip Files/trips starting 2019-02-08.csv
# CAD Data/Trip Files/trips starting 2019-02-09.csv
# CAD Data/Trip Files/trips starting 2019-02-10.csv
# CAD Data/Trip Files/trips starting 2019-02-11.csv
# CAD Data/Trip Files/trips starting 2019-02-12.csv
# CAD Data/Trip Files/trips starting 2019-02-13.csv
# CAD Data/Trip Files/trips starting 2019-02-14.csv
# CAD Data/Trip Files/trips starting 2019-02-15.csv
# CAD Data/Trip Files/trips starting 2019-02-16.csv
# CAD Data/Trip Files/trips starting 2019-02-17.csv
# CAD Data/Trip Files/trips starting 2019-02-18.csv
# CAD Data/Trip Files/trips starting 2019-02-19.csv
# CAD Data/Trip Files/trips starting 2019-02-20.csv
# CAD Data/Trip Files/trips starting 2019-02-21.csv
# CAD Data/Trip Files/trips starting 2019-02-22.csv
# CAD Data/Trip Files/trips starting 2019-02-23.csv
# CAD Data/Trip Files/trips starting 2019-02-24.csv
# CAD Data/Trip Files/trips starting 2019-02-25.csv
# CAD Data/Trip Files/trips starting 2019-02-26.csv
# CAD Data/Trip Files/trips starting 2019-02-27.csv
# CAD Data/Trip Files/trips starting 2019-02-28.csv
# CAD Data/Trip Files/trips starting 2019-03-01.csv
# CAD Data/Trip Files/trips starting 2019-03-02.csv
# CAD Data/Trip Files/trips starting 2019-03-03.csv
# CAD Data/Trip Files/trips starting 2019-03-04.csv
# CAD Data/Trip Files/trips starting 2019-03-05.csv
# CAD Data/Trip Files/trips starting 2019-03-06.csv
# CAD Data/Trip Files/trips starting 2019-03-07.csv
# CAD Data/Trip Files/trips starting 2019-03-08.csv
# CAD Data/Trip Files/trips starting 2019-03-09.csv
# CAD Data/Trip Files/trips starting 2019-03-10.csv
# CAD Data/Trip Files/trips starting 2019-03-11.csv
# CAD Data/Trip Files/trips starting 2019-03-12.csv
# CAD Data/Trip Files/trips starting 2019-03-13.csv
# CAD Data/Trip Files/trips starting 2019-03-14.csv
# CAD Data/Trip Files/trips starting 2019-03-15.csv
# CAD Data/Trip Files/trips starting 2019-03-16.csv
# CAD Data/Trip Files/trips starting 2019-03-17.csv
# CAD Data/Trip Files/trips starting 2019-03-18.csv
# CAD Data/Trip Files/trips starting 2019-03-19.csv
# CAD Data/Trip Files/trips starting 2019-03-20.csv
# CAD Data/Trip Files/trips starting 2019-03-21.csv
# CAD Data/Trip Files/trips starting 2019-03-22.csv
# CAD Data/Trip Files/trips starting 2019-03-23.csv
# CAD Data/Trip Files/trips starting 2019-03-24.csv
# CAD Data/Trip Files/trips starting 2019-03-25.csv
# CAD Data/Trip Files/trips starting 2019-03-26.csv
# CAD Data/Trip Files/trips starting 2019-03-27.csv
# CAD Data/Trip Files/trips starting 2019-03-28.csv
# CAD Data/Trip Files/trips starting 2019-03-29.csv
# CAD Data/Trip Files/trips starting 2019-03-30.csv
# CAD Data/Trip Files/trips starting 2019-03-31.csv
# CAD Data/Trip Files/trips starting 2019-04-01.csv
# CAD Data/Trip Files/trips starting 2019-04-02.csv
# CAD Data/Trip Files/trips starting 2019-04-03.csv
# CAD Data/Trip Files/trips starting 2019-04-04.csv
# CAD Data/Trip Files/trips starting 2019-04-05.csv
# CAD Data/Trip Files/trips starting 2019-04-06.csv
# CAD Data/Trip Files/trips starting 2019-04-07.csv
# CAD Data/Trip Files/trips starting 2019-04-08.csv
# CAD Data/Trip Files/trips starting 2019-04-09.csv
# CAD Data/Trip Files/trips starting 2019-04-10.csv
# CAD Data/Trip Files/trips starting 2019-04-11.csv
# CAD Data/Trip Files/trips starting 2019-04-12.csv
# CAD Data/Trip Files/trips starting 2019-04-13.csv
# CAD Data/Trip Files/trips starting 2019-04-14.csv
# CAD Data/Trip Files/trips starting 2019-04-15.csv
# CAD Data/Trip Files/trips starting 2019-04-16.csv
# CAD Data/Trip Files/trips starting 2019-04-17.csv
# CAD Data/Trip Files/trips starting 2019-04-18.csv
# CAD Data/Trip Files/trips starting 2019-04-19.csv
# CAD Data/Trip Files/trips starting 2019-04-20.csv
# CAD Data/Trip Files/trips starting 2019-04-21.csv
# CAD Data/Trip Files/trips starting 2019-04-22.csv
# CAD Data/Trip Files/trips starting 2019-04-23.csv
# CAD Data/Trip Files/trips starting 2019-04-24.csv
# CAD Data/Trip Files/trips starting 2019-04-25.csv
# CAD Data/Trip Files/trips starting 2019-04-26.csv
# CAD Data/Trip Files/trips starting 2019-04-27.csv
# CAD Data/Trip Files/trips starting 2019-04-28.csv
# CAD Data/Trip Files/trips starting 2019-04-29.csv
